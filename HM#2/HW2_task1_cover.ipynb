# %% [markdown]
# # Problem Set 2 - Data preparation

# %% [markdown]
# _Data Preparation Course at UCU, 2019_

# %% [markdown]
# ### NB
#
# __1) Which programming languages to use?__
#
# You can use Python, R or both of them (but with one limitation: one dataset - one language).
#
# __2) What libraries/packages to use?__
#
# You are free to choose any appropriate data processing libraries (good choice would be __pandas__, __numpy__ or
# __pyspark__ for Python and __dplyr__ or __tidyr__ for R).
#
# __3) How to summarize my homework?__
#
# The best way is to create an individual Jupyter/R notebook with code and explanations for each dataset.
# In case you are not familiar with these tools, you can create a Python/R scripts and write explanations
# as comments. However, we strongly recommend you to use Jupyter/R notebooks, as those are #1 tools in
# applied data analysis nowadays.

# %% [markdown]
# ### Task 1
#
# ### Data integration (Ukrainian Vehicles Data Set)

# %% [markdown]
# Load the appropriate libraries.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import csv

# %% [markdown]
# __1.1.__ Download the dataset from Ukrainian Open Data Portal [__(dataset)__](https://data.gov.ua/dataset/06779371-308f-42d7-895e-5a39833375f0/resource/01323740-88df-46c2-b06e-fbb58c89fe17).

# %% [markdown]
# __1.2.__ Read the data, remove quotes, trailing whitespaces and tabs.

# %%
df = pd.read_csv('tz_opendata_z01012018_po01012019.csv', encoding ="utf-8",  sep=';')

# %%
df.head(5)
# Out:
#   person  reg_addr_koatuu  oper_code  \
# 0      J     6.510000e+09        100
# 1      P     6.510137e+09        100
# 2      P     6.510137e+09        100
# 3      J     6.510137e+09        100
# 4      P     1.412337e+09        530
#
#                                            oper_name       d_reg  dep_code  \
# 0  100 - ПЕРВИННА РЕЄСТРАЦIЯ ТЗ ПРИДБАНОГО В ТОРГ...  2018-08-02      3246
# 1  100 - ПЕРВИННА РЕЄСТРАЦIЯ ТЗ ПРИДБАНОГО В ТОРГ...  2018-08-01      5141
# 2  100 - ПЕРВИННА РЕЄСТРАЦIЯ ТЗ ПРИДБАНОГО В ТОРГ...  2018-08-02      5141
# 3  100 - ПЕРВИННА РЕЄСТРАЦIЯ ТЗ ПРИДБАНОГО В ТОРГ...  2018-08-01      3246
# 4               530 - ЗНЯТТЯ З ОБЛIКУ ДЛЯ РЕАЛIЗАЦIЇ  2018-03-06      5946
#
#           dep             brand     model  make_year   color      kind  \
# 0  Центр 3246         ACURA MDX       MDX       2018   БІЛИЙ  ЛЕГКОВИЙ
# 1  Центр 5141     KIA  SPORTAGE  SPORTAGE       2018   СІРИЙ   АВТОБУС
# 2  Центр 5141           AUDI A7        А7       2018   СІРИЙ  ЛЕГКОВИЙ
# 3  Центр 3246            BMW X5        X5       2018  ЧОРНИЙ  ЛЕГКОВИЙ
# 4    ТСЦ 5946  VOLKSWAGEN  GOLF      GOLF       1991   СИНІЙ  ЛЕГКОВИЙ
#
#           body    purpose             fuel  capacity  own_weight  \
# 0      СЕДАН-В  ЗАГАЛЬНИЙ  ДИЗЕЛЬНЕ ПАЛИВО    2048.0      2600.0
# 1  УНІВЕРСАЛ-B  ЗАГАЛЬНИЙ  ДИЗЕЛЬНЕ ПАЛИВО    1685.0      2100.0
# 2        СЕДАН  ЗАГАЛЬНИЙ  ДИЗЕЛЬНЕ ПАЛИВО    1685.0      2100.0
# 3        СЕДАН  ЗАГАЛЬНИЙ  ДИЗЕЛЬНЕ ПАЛИВО    1685.0      2500.0
# 4    ХЕТЧБЕК-В  ЗАГАЛЬНИЙ  ДИЗЕЛЬНЕ ПАЛИВО    1896.0      1060.0
#
#    total_weight n_reg_new
# 0        3500.0  AI7441AP
# 1        3500.0  ВТ1885АА
# 2        3500.0  ВТ1888АА
# 3        3500.0  АІ1847АВ
# 4        1585.0  19АІ5324

# %% [markdown]
# __1.3.__ Find and remove duplicates (if any)

# %%
print(df.size , "- wiht duplicates")
df = df.drop_duplicates()
print(df.size, "- after remove duplicates")
# Out:
# 29400942 - wiht duplicates
# 29377914 - after remove duplicates

# %% [markdown]
# __1.4.__ Save a dictionary of unique operation codes and its meanings in external file (op_codes.txt). Column
# __oper_name__ is redundant and we probably won’t need it in our data analysis, but it could be a good
# reference to better understand our data. Drop this column and think about any other redundant columns.
# If you find any, explain why you think of them being redundant?

# %% [markdown]
# #### Getting unic codes.

# %%
# This same step is also aplicable for dep and dep_code columns, dep is not giving info to the dataset, it is just a
# description of the dep_codes column. So i can be droped as well.
oper_codes_names = df[['oper_code','oper_name']]
print(oper_codes_names.size, "- oper")
oper_codes_names = oper_codes_names.drop_duplicates()
print(oper_codes_names.size, "- oper")

dep_codes_names = df[['dep_code','dep']]
print(dep_codes_names.size, "- dep")
dep_codes_names = dep_codes_names.drop_duplicates()
print(dep_codes_names.size, "- dep")


oper_codes_names.head(10)
# Out:
# 3092412 - oper
# 278 - oper
# 3092412 - dep
# 350 - dep
#     oper_code                                          oper_name
# 0         100  100 - ПЕРВИННА РЕЄСТРАЦIЯ ТЗ ПРИДБАНОГО В ТОРГ...
# 4         530               530 - ЗНЯТТЯ З ОБЛIКУ ДЛЯ РЕАЛIЗАЦIЇ
# 5         255  255 -  АНУЛЮВАННЯ ВИДАЧI ТИМЧАС. РЕЄСТРАЦIЙНОГ...
# 6         560  560 -  ЗНЯТТЯ З ОБЛІКУ ПРИ ПОВЕРНЕННІ ІЗ ПОЇЗД...
# 7         430  430 - ПЕРЕРЕЄСТРАЦІЯ ПРИ ЗАМІНІ СВІДОЦТВА ПРО ...
# 9          49  49 - ВТОРИННА РЕЄСТРАЦІЯ ТЗ ПО ДОГОВОРУ УКЛАДЕ...
# 10         40  40 - ВТОРИННА РЕЄСТРАЦІЯ ТЗ, ПРИДБАНОГО В ТОРГ...
# 11        319  319 - ПЕРЕРЕЄСТРАЦІЯ ТЗ НА НОВОГО ВЛАСНИКА ЗА ...
# 13        315  315 - ПЕРЕРЕЄСТРАЦІЯ ТЗ НА НОВ. ВЛАСН. ПО ДОГО...
# 14        440  440 - ПЕРЕРЕЄСТРАЦIЯ ПРИ ВТРАТІ СВIДОЦТВА ПРО ...

# %% [markdown]
# #### Creating oper codes and dep codes dictionaries.

# %%
oper_codes_dict = {}
dep_codes_dict = {}
for index, row in oper_codes_names.iterrows():
    oper_codes_dict[row['oper_code']] = row['oper_name']
    
    
#print(codes_dict)
for index, row in dep_codes_names.iterrows():
    dep_codes_dict[row['dep_code']] = row['dep']

# %% [markdown]
# #### Saving resulting dictionaries to files

# %%
# as requested in comment

f = open("op_codes.txt","w", encoding="utf-8")
f.write( str(oper_codes_dict) )
f.close()

f = open("dep_codes.txt","w", encoding="utf-8")
f.write( str(dep_codes_dict) )
f.close()

# %% [markdown]
# #### Droping oper_name and dep columns, as they are just description of the data

# %%
df = df.drop(['oper_name'], axis=1)
df = df.drop(['dep'], axis=1)
df.head(4)
# Out:
#   person  reg_addr_koatuu  oper_code       d_reg  dep_code          brand  \
# 0      J     6.510000e+09        100  2018-08-02      3246      ACURA MDX
# 1      P     6.510137e+09        100  2018-08-01      5141  KIA  SPORTAGE
# 2      P     6.510137e+09        100  2018-08-02      5141        AUDI A7
# 3      J     6.510137e+09        100  2018-08-01      3246         BMW X5
#
#       model  make_year   color      kind         body    purpose  \
# 0       MDX       2018   БІЛИЙ  ЛЕГКОВИЙ      СЕДАН-В  ЗАГАЛЬНИЙ
# 1  SPORTAGE       2018   СІРИЙ   АВТОБУС  УНІВЕРСАЛ-B  ЗАГАЛЬНИЙ
# 2        А7       2018   СІРИЙ  ЛЕГКОВИЙ        СЕДАН  ЗАГАЛЬНИЙ
# 3        X5       2018  ЧОРНИЙ  ЛЕГКОВИЙ        СЕДАН  ЗАГАЛЬНИЙ
#
#               fuel  capacity  own_weight  total_weight n_reg_new
# 0  ДИЗЕЛЬНЕ ПАЛИВО    2048.0      2600.0        3500.0  AI7441AP
# 1  ДИЗЕЛЬНЕ ПАЛИВО    1685.0      2100.0        3500.0  ВТ1885АА
# 2  ДИЗЕЛЬНЕ ПАЛИВО    1685.0      2100.0        3500.0  ВТ1888АА
# 3  ДИЗЕЛЬНЕ ПАЛИВО    1685.0      2500.0        3500.0  АІ1847АВ

# %% [markdown]
# __1.5.__ Translate at least 3 attributes’ values to English (color, kind, etc.).

# %% [markdown]
# #### Translating the 'color' column

# %%
color_set = df['color'].drop_duplicates()
color_set.size
translated_dict = { 
    "БІЛИЙ":"WHITE",
    "СІРИЙ":"GRAY",
    "ЧОРНИЙ":"BLACK",
    "СИНІЙ":"BLUE",
    "ЗЕЛЕНИЙ":"GREAN",
    "ЖОВТИЙ":"YELLOW",
    "ЧЕРВОНИЙ":"RED",
    "ОРАНЖЕВИЙ":"ORANGE",
    "БЕЖЕВИЙ":"BEIGE",
    "КОРИЧНЕВИЙ":"BROWN",
    "ФІОЛЕТОВИЙ":"PURPLE",
    "НЕВИЗНАЧЕНИЙ":"UNDEFINED"
}
# wanted to use google translate api, but I was blocked with very frequent request.
# df["color"] = df["color"].map(lambda x: translator.translate(x).text)
df['color'] = df['color'].map(translated_dict)
df.head(4)
# Out:
#   person  reg_addr_koatuu  oper_code       d_reg  dep_code          brand  \
# 0      J     6.510000e+09        100  2018-08-02      3246      ACURA MDX
# 1      P     6.510137e+09        100  2018-08-01      5141  KIA  SPORTAGE
# 2      P     6.510137e+09        100  2018-08-02      5141        AUDI A7
# 3      J     6.510137e+09        100  2018-08-01      3246         BMW X5
#
#       model  make_year  color      kind         body    purpose  \
# 0       MDX       2018  WHITE  ЛЕГКОВИЙ      СЕДАН-В  ЗАГАЛЬНИЙ
# 1  SPORTAGE       2018   GRAY   АВТОБУС  УНІВЕРСАЛ-B  ЗАГАЛЬНИЙ
# 2        А7       2018   GRAY  ЛЕГКОВИЙ        СЕДАН  ЗАГАЛЬНИЙ
# 3        X5       2018  BLACK  ЛЕГКОВИЙ        СЕДАН  ЗАГАЛЬНИЙ
#
#               fuel  capacity  own_weight  total_weight n_reg_new
# 0  ДИЗЕЛЬНЕ ПАЛИВО    2048.0      2600.0        3500.0  AI7441AP
# 1  ДИЗЕЛЬНЕ ПАЛИВО    1685.0      2100.0        3500.0  ВТ1885АА
# 2  ДИЗЕЛЬНЕ ПАЛИВО    1685.0      2100.0        3500.0  ВТ1888АА
# 3  ДИЗЕЛЬНЕ ПАЛИВО    1685.0      2500.0        3500.0  АІ1847АВ

# %% [markdown]
# #### Translating the 'kind' column

# %%
kind_set = df['kind'].drop_duplicates()
kind_set.size
translated_dict = { 
    "ЛЕГКОВИЙ":"CAR",
    "АВТОБУС":"BUS",
    "ВАНТАЖНИЙ":"Truck",
    "ПРИЧІП":"TRAILER",
    "МОТОЦИКЛ":"MOTORCYCLE",
    "НАПІВПРИЧІП":"SEMI-TRAILER",
    "МОПЕД":"MOPED",
    "КВАДРОЦИКЛ":"ATV",
    "ТРИЦИКЛ":"TRICYCLE",
    "СПЕЦІАЛІЗОВАНІ":"SPECIALIZED"
}
df['kind'] = df['kind'].map(translated_dict)
df.head(4)
# Out:
# 0               ЛЕГКОВИЙ
# 1                АВТОБУС
# 8              ВАНТАЖНИЙ
# 26                ПРИЧІП
# 80              МОТОЦИКЛ
# 139          НАПІВПРИЧІП
# 142                МОПЕД
# 968           КВАДРОЦИКЛ
# 3980             ТРИЦИКЛ
# 398379    СПЕЦІАЛІЗОВАНІ
# Name: kind, dtype: object
#   person  reg_addr_koatuu  oper_code       d_reg  dep_code          brand  \
# 0      J     6.510000e+09        100  2018-08-02      3246      ACURA MDX
# 1      P     6.510137e+09        100  2018-08-01      5141  KIA  SPORTAGE
# 2      P     6.510137e+09        100  2018-08-02      5141        AUDI A7
# 3      J     6.510137e+09        100  2018-08-01      3246         BMW X5
#
#       model  make_year  color kind         body    purpose             fuel  \
# 0       MDX       2018  WHITE  CAR      СЕДАН-В  ЗАГАЛЬНИЙ  ДИЗЕЛЬНЕ ПАЛИВО
# 1  SPORTAGE       2018   GRAY  BUS  УНІВЕРСАЛ-B  ЗАГАЛЬНИЙ  ДИЗЕЛЬНЕ ПАЛИВО
# 2        А7       2018   GRAY  CAR        СЕДАН  ЗАГАЛЬНИЙ  ДИЗЕЛЬНЕ ПАЛИВО
# 3        X5       2018  BLACK  CAR        СЕДАН  ЗАГАЛЬНИЙ  ДИЗЕЛЬНЕ ПАЛИВО
#
#    capacity  own_weight  total_weight n_reg_new
# 0    2048.0      2600.0        3500.0  AI7441AP
# 1    1685.0      2100.0        3500.0  ВТ1885АА
# 2    1685.0      2100.0        3500.0  ВТ1888АА
# 3    1685.0      2500.0        3500.0  АІ1847АВ

# %% [markdown]
# #### Translating the purpose column

# %%
purpose_set = df['purpose'].drop_duplicates()
translated_dict = { 
    "ЗАГАЛЬНИЙ":"GENERAL",
    "СПЕЦІАЛІЗОВАНИЙ":"SPECIALIZED",
    "СПЕЦІАЛЬНИЙ":"SPECIAL"
}
df['purpose'] = df['purpose'].map(translated_dict)
df.head(4)
# Out:
#   person  reg_addr_koatuu  oper_code       d_reg  dep_code          brand  \
# 0      J     6.510000e+09        100  2018-08-02      3246      ACURA MDX
# 1      P     6.510137e+09        100  2018-08-01      5141  KIA  SPORTAGE
# 2      P     6.510137e+09        100  2018-08-02      5141        AUDI A7
# 3      J     6.510137e+09        100  2018-08-01      3246         BMW X5
#
#       model  make_year  color kind         body  purpose             fuel  \
# 0       MDX       2018  WHITE  CAR      СЕДАН-В  GENERAL  ДИЗЕЛЬНЕ ПАЛИВО
# 1  SPORTAGE       2018   GRAY  BUS  УНІВЕРСАЛ-B  GENERAL  ДИЗЕЛЬНЕ ПАЛИВО
# 2        А7       2018   GRAY  CAR        СЕДАН  GENERAL  ДИЗЕЛЬНЕ ПАЛИВО
# 3        X5       2018  BLACK  CAR        СЕДАН  GENERAL  ДИЗЕЛЬНЕ ПАЛИВО
#
#    capacity  own_weight  total_weight n_reg_new
# 0    2048.0      2600.0        3500.0  AI7441AP
# 1    1685.0      2100.0        3500.0  ВТ1885АА
# 2    1685.0      2100.0        3500.0  ВТ1888АА
# 3    1685.0      2500.0        3500.0  АІ1847АВ

# %% [markdown]
# #### Translating the fuel column

# %%
fuel_set = df['fuel'].drop_duplicates()
fuel_set.head(11)
translated_dict = { 
    "ДИЗЕЛЬНЕ ПАЛИВО":"DIESEL",
    "БЕНЗИН":"GASOLINE",
    "БЕНЗИН АБО ГАЗ":"GASOLINE OR GAS",
    "ЕЛЕКТРО АБО БЕНЗИН":"ELECTRIC OR GASOLINE",
    "ДИЗЕЛЬНЕ ПАЛИВО АБО ГАЗ":"DIESEL OR GAS",
    "ЕЛЕКТРО":"ELECTRIC",
    "НЕ ВИЗНАЧЕНО":"UNDEFINED",
    "ГАЗ":"GAS",
    "ЕЛЕКТРО АБО ДИЗЕЛЬНЕ ПАЛИВО":"ELECTRO OR DIESEL",
    "БЕНЗИН, ГАЗ АБО ЕЛЕКТРО":"GASOLINE, GAS OR ELECTRIC"
}
df['fuel'] = df['fuel'].map(translated_dict)
df.head(4)
# Out:
#   person  reg_addr_koatuu  oper_code       d_reg  dep_code          brand  \
# 0      J     6.510000e+09        100  2018-08-02      3246      ACURA MDX
# 1      P     6.510137e+09        100  2018-08-01      5141  KIA  SPORTAGE
# 2      P     6.510137e+09        100  2018-08-02      5141        AUDI A7
# 3      J     6.510137e+09        100  2018-08-01      3246         BMW X5
#
#       model  make_year  color kind         body  purpose    fuel  capacity  \
# 0       MDX       2018  WHITE  CAR      СЕДАН-В  GENERAL  DIESEL    2048.0
# 1  SPORTAGE       2018   GRAY  BUS  УНІВЕРСАЛ-B  GENERAL  DIESEL    1685.0
# 2        А7       2018   GRAY  CAR        СЕДАН  GENERAL  DIESEL    1685.0
# 3        X5       2018  BLACK  CAR        СЕДАН  GENERAL  DIESEL    1685.0
#
#    own_weight  total_weight n_reg_new
# 0      2600.0        3500.0  AI7441AP
# 1      2100.0        3500.0  ВТ1885АА
# 2      2100.0        3500.0  ВТ1888АА
# 3      2500.0        3500.0  АІ1847АВ

# %% [markdown]
# __1.6.__ Think about which column names are not clear enough and change them

# %%
df.columns = ["person","registration_address_koatuu","oper_code",
              "registration_date", "dep_code", "brand", "model", 
              "made_year", "color", "kind", "body_type", "purpose",
              "fuel_type", "capacity", "own_weight", "total_weight",
              "registration_plates"]

# %%
df.head(5)
# Out:
#   person  registration_address_koatuu  oper_code registration_date  dep_code  \
# 0      J                 6.510000e+09        100        2018-08-02      3246
# 1      P                 6.510137e+09        100        2018-08-01      5141
# 2      P                 6.510137e+09        100        2018-08-02      5141
# 3      J                 6.510137e+09        100        2018-08-01      3246
# 4      P                 1.412337e+09        530        2018-03-06      5946
#
#               brand     model  made_year  color kind    body_type  purpose  \
# 0         ACURA MDX       MDX       2018  WHITE  CAR      СЕДАН-В  GENERAL
# 1     KIA  SPORTAGE  SPORTAGE       2018   GRAY  BUS  УНІВЕРСАЛ-B  GENERAL
# 2           AUDI A7        А7       2018   GRAY  CAR        СЕДАН  GENERAL
# 3            BMW X5        X5       2018  BLACK  CAR        СЕДАН  GENERAL
# 4  VOLKSWAGEN  GOLF      GOLF       1991   BLUE  CAR    ХЕТЧБЕК-В  GENERAL
#
#   fuel_type  capacity  own_weight  total_weight registration_plates
# 0    DIESEL    2048.0      2600.0        3500.0            AI7441AP
# 1    DIESEL    1685.0      2100.0        3500.0            ВТ1885АА
# 2    DIESEL    1685.0      2100.0        3500.0            ВТ1888АА
# 3    DIESEL    1685.0      2500.0        3500.0            АІ1847АВ
# 4    DIESEL    1896.0      1060.0        1585.0            19АІ5324

# %% [markdown]
# __1.7.__ What is the possible usage of this data? Give 2-3 examples?

# %% [markdown]
# __1.8.__ Save the result of your work as a regular .csv file

# %% [markdown]
# __1.9.__ What is the most popular car and car color in Ukraine?

# %% [markdown]
# ### Most popular car color

# %%
df['color'].mode()
Most popular car color
# Out:
# 0    GRAY
# dtype: object

# %% [markdown]
# ### Most popular car

# %%
df['brand'].mode()
# Out:
# 0    DAEWOO  LANOS
# dtype: object
